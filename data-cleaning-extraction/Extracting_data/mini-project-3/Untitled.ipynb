# %% [markdown]
# #Here I am working on a file Riders Summary
#
# #Let's print the data using pandas

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('RidersSummary.csv')

# %%
df1
# Out:
#      bike_number    rider_name   class  season home_country  \
# 0              1  Jorge Martin   Moto3    2015        Spain
# 1              1  Jorge Martin   Moto3    2016        Spain
# 2              1  Jorge Martin   Moto3    2017        Spain
# 3              1  Jorge Martin   Moto3    2018        Spain
# 4              1  Jorge Martin   Moto2    2019        Spain
# ..           ...           ...     ...     ...          ...
# 269           93  Marc Marquez  MotoGP    2021        Spain
# 270           93  Marc Marquez  MotoGP    2022        Spain
# 271           93  Marc Marquez  MotoGP    2023        Spain
# 272           93  Marc Marquez  MotoGP    2024        Spain
# 273           93  Marc Marquez  MotoGP    2025        Spain
#
#                   motorcycle                             team  \
# 0                   Mahindra             Mapfre Team Mahindra
# 1                   Mahindra  Pull & Bear Aspar Mahindra Team
# ...

# %% [markdown]
# #Question1
#
# #How many Unique motor cycle brands are there?

# %%
df1['motorcycle'].nunique()
# Out:
# 33

# %% [markdown]
# #Question2
#
# #What are the unique rider classes available( e.g. motoGP, moto2)?

# %%
df1['class'].nunique()
# Out:
# 5

# %%
df1['class'].unique()
# Out:
# array(['Moto3', 'Moto2', 'MotoGP', '125cc', 'MotoE'], dtype=object)

# %% [markdown]
# #Question3
#
# #Which team has highest number of riders?

# %%
df1['team'].nunique() #Finding the number of teams
# Out:
# 85

# %%
df2 = df1.groupby('team')

# %%
print(df2['team'].count().idxmax())
df2['team'].count().max()
#So the team with highest riders is:
# Out:
# Red Bull KTM Ajo
# 17

# %% [markdown]
# #Question4
#
# #find all riders who have participated in 20 races.

# %%
df1[df1['races_participated'] == 20]
# Out:
#      bike_number             rider_name   class  season  home_country  \
# 7              1           Jorge Martin  MotoGP    2022         Spain
# 8              1           Jorge Martin  MotoGP    2023         Spain
# 9              1           Jorge Martin  MotoGP    2024         Spain
# 25             5           Johann Zarco  MotoGP    2022        France
# 26             5           Johann Zarco  MotoGP    2023        France
# 27             5           Johann Zarco  MotoGP    2024        France
# 37            10            Luca Marini  MotoGP    2022         Italy
# 53            12       Maverick Vinales  MotoGP    2022         Spain
# 54            12       Maverick Vinales  MotoGP    2023         Spain
# 55            12       Maverick Vinales  MotoGP    2024         Spain
# 64            20       Fabio Quartararo  MotoGP    2022        France
# 65            20       Fabio Quartararo  MotoGP    2023        France
# ...

# %% [markdown]
# #Question5
#
# #Extract records where riders have won at least 1 World ChampionShip

# %%
df1[df1['world_championships'] >=1]
# Out:
#      bike_number         rider_name   class  season  home_country  \
# 3              1       Jorge Martin   Moto3    2018         Spain
# 9              1       Jorge Martin  MotoGP    2024         Spain
# 17             5       Johann Zarco   Moto2    2015        France
# 18             5       Johann Zarco   Moto2    2016        France
# 43            12   Maverick Vinales   Moto3    2013         Spain
# 63            20   Fabio Quartararo  MotoGP    2021        France
# 72            21  Franco Morbidelli   Moto2    2017         Italy
# 88            23    Enea Bastianini   Moto2    2020         Italy
# 112           33        Brad Binder   Moto3    2016  South Africa
# 132           36           Joan Mir   Moto3    2017         Spain
# 135           36           Joan Mir  MotoGP    2020         Spain
# 141           37       Pedro Acosta   Moto3    2021         Spain
# 143           37       Pedro Acosta   Moto2    2023         Spain
# ...

# %% [markdown]
# #Question6
#
# #Find riders from a specific motor cycle brand

# %%
#Honda
df1[df1['motorcycle'] == 'Honda']
# Out:
#      bike_number             rider_name   class  season home_country  \
# 2              1           Jorge Martin   Moto3    2017        Spain
# 3              1           Jorge Martin   Moto3    2018        Spain
# 22             5           Johann Zarco  MotoGP    2019       France
# 27             5           Johann Zarco  MotoGP    2024       France
# 28             5           Johann Zarco  MotoGP    2025       France
# 39            10            Luca Marini  MotoGP    2024        Italy
# 40            10            Luca Marini  MotoGP    2025        Italy
# 57            20       Fabio Quartararo   Moto3    2015       France
# 73            21      Franco Morbidelli  MotoGP    2018        Italy
# 83            23        Enea Bastianini   Moto3    2015        Italy
# 84            23        Enea Bastianini   Moto3    2016        Italy
# 85            23        Enea Bastianini   Moto3    2017        Italy
# 86            23        Enea Bastianini   Moto3    2018        Italy
# ...

# %% [markdown]
# #Question 7
#
# #which rider has scored the highest points?

# %%
df1['rider_name'].loc[df1['points'].idxmax()]
# Out:
# 'Jorge Martin'

# %% [markdown]
# #Question 8
#
# #List the top 5 riders with the number of wins

# %%
sorting_table = df1.sort_values(by = "wins",ascending = False)  #These are sorted in ascending order 
sorting_table[0:5]
# Out:
#      bike_number         rider_name   class  season home_country  \
# 262           93       Marc Marquez  MotoGP    2014        Spain
# 267           93       Marc Marquez  MotoGP    2019        Spain
# 204           63  Francesco Bagnaia  MotoGP    2024        Italy
# 132           36           Joan Mir   Moto3    2017        Spain
# 258           93       Marc Marquez   125cc    2010        Spain
#
#         motorcycle                     team  races_participated  wins  podium  \
# 262   Honda RC213V        Repsol Honda Team                  18    13      14
# 267   Honda RC213V        Repsol Honda Team                  19    12      18
# 204         Ducati       Ducati Lenovo Team                  20    11      16
# 132          Honda           Leopard Racing                  18    10      13
# 258  Derbi RSA 125  Red Bull Ajo Motorsport                  17    10      12
#
#      pole  fastest_lap  points  placed  world_championships
# ...

# %%
# or
df1.nlargest(5,'wins')
# Out:
#      bike_number         rider_name   class  season home_country  \
# 262           93       Marc Marquez  MotoGP    2014        Spain
# 267           93       Marc Marquez  MotoGP    2019        Spain
# 204           63  Francesco Bagnaia  MotoGP    2024        Italy
# 132           36           Joan Mir   Moto3    2017        Spain
# 258           93       Marc Marquez   125cc    2010        Spain
#
#         motorcycle                     team  races_participated  wins  podium  \
# 262   Honda RC213V        Repsol Honda Team                  18    13      14
# 267   Honda RC213V        Repsol Honda Team                  19    12      18
# 204         Ducati       Ducati Lenovo Team                  20    11      16
# 132          Honda           Leopard Racing                  18    10      13
# 258  Derbi RSA 125  Red Bull Ajo Motorsport                  17    10      12
#
#      pole  fastest_lap  points  placed  world_championships
# ...

# %% [markdown]
# #Question 9
#
# #Rank riders based on the podiums(most to least)

# %%
df1.sort_values('podium',ascending = False)
# Out:
#      bike_number         rider_name   class  season home_country  \
# 267           93       Marc Marquez  MotoGP    2019        Spain
# 9              1       Jorge Martin  MotoGP    2024        Spain
# 261           93       Marc Marquez  MotoGP    2013        Spain
# 204           63  Francesco Bagnaia  MotoGP    2024        Italy
# 203           63  Francesco Bagnaia  MotoGP    2023        Italy
# ..           ...                ...     ...     ...          ...
# 129           35    Somkiat Chantra  MotoGP    2025     Thailand
# 130           36           Joan Mir   Moto3    2015        Spain
# 134           36           Joan Mir  MotoGP    2019        Spain
# 138           36           Joan Mir  MotoGP    2023        Spain
# 137           36           Joan Mir  MotoGP    2022        Spain
#
#        motorcycle                 team  races_participated  wins  podium  \
# 267  Honda RC213V    Repsol Honda Team                  19    12      18
# ...

# %% [markdown]
# #Question 10
#
# #What is the average number of wins per class?

# %%
df1.groupby('class')['wins'].mean()
# Out:
# class
# 125cc     1.250000
# Moto2     1.984375
# Moto3     1.245902
# MotoE     0.000000
# MotoGP    1.132353
# Name: wins, dtype: float64

# %% [markdown]
# #Question 11
#
# #Which motor cycle brand has the most total wins?

# %%
df1.groupby('motorcycle')['wins'].sum().idxmax()
# Out:
# 'Kalex'

# %% [markdown]
# #Question 12
#
# #How many riders are there per team?

# %%
df1.groupby('team')['rider_name'].count()
#or
df1['team'].value_counts()  #It gives the output in descending order
# Out:
# team
# Red Bull KTM Ajo               17
# Repsol Honda Team              15
# Red Bull KTM Factory Racing    12
# Team Suzuki Ecstar             12
# EG 0,0 Marc VDS                11
#                                ..
# Andalucía Banca Cívica          1
# AP Honda Racing Thailand        1
# Red Bull GasGas Tech3           1
# Aprilia Racing Team Gresini     1
# RZT Racing                      1
# Name: count, Length: 85, dtype: int64

# %% [markdown]
# #Question 13
#
# #Add a column showing the average points per race.

# %%
df1['avg_points_per_race'] = df1['points']/df1['races_participated']

# %%
df1
# Out:
#      bike_number    rider_name   class  season home_country  \
# 0              1  Jorge Martin   Moto3    2015        Spain
# 1              1  Jorge Martin   Moto3    2016        Spain
# 2              1  Jorge Martin   Moto3    2017        Spain
# 3              1  Jorge Martin   Moto3    2018        Spain
# 4              1  Jorge Martin   Moto2    2019        Spain
# ..           ...           ...     ...     ...          ...
# 269           93  Marc Marquez  MotoGP    2021        Spain
# 270           93  Marc Marquez  MotoGP    2022        Spain
# 271           93  Marc Marquez  MotoGP    2023        Spain
# 272           93  Marc Marquez  MotoGP    2024        Spain
# 273           93  Marc Marquez  MotoGP    2025        Spain
#
#                   motorcycle                             team  \
# 0                   Mahindra             Mapfre Team Mahindra
# 1                   Mahindra  Pull & Bear Aspar Mahindra Team
# ...

# %% [markdown]
# #Question 14
#
# #Identify the riders who have never finished on the podium

# %%
df1[df1['podium'] == 0]
# Out:
#      bike_number       rider_name   class  season home_country    motorcycle  \
# 0              1     Jorge Martin   Moto3    2015        Spain      Mahindra
# 10             1     Jorge Martin  MotoGP    2025        Spain       Aprilia
# 11             5     Johann Zarco   125cc    2009       France       Aprilia
# 12             5     Johann Zarco   125cc    2010       France       Aprilia
# 14             5     Johann Zarco   Moto2    2012       France        Motobi
# ..           ...              ...     ...     ...          ...           ...
# 249           88  Miguel Oliveira  MotoGP    2019     Portugal           KTM
# 253           88  Miguel Oliveira  MotoGP    2023     Portugal       Aprilia
# 254           88  Miguel Oliveira  MotoGP    2024     Portugal       Aprilia
# 255           88  Miguel Oliveira  MotoGP    2025     Portugal        Yamaha
# 268           93     Marc Marquez  MotoGP    2020        Spain  Honda RC213V
#
# ...

# %% [markdown]
# #Question 15
#
# #Create a new column that classifies riders as "Champion" if they have at least one world championship

# %%
df1['is_champion'] = df1['world_championships']>0
df1
# Out:
#      bike_number    rider_name   class  season home_country  \
# 0              1  Jorge Martin   Moto3    2015        Spain
# 1              1  Jorge Martin   Moto3    2016        Spain
# 2              1  Jorge Martin   Moto3    2017        Spain
# 3              1  Jorge Martin   Moto3    2018        Spain
# 4              1  Jorge Martin   Moto2    2019        Spain
# ..           ...           ...     ...     ...          ...
# 269           93  Marc Marquez  MotoGP    2021        Spain
# 270           93  Marc Marquez  MotoGP    2022        Spain
# 271           93  Marc Marquez  MotoGP    2023        Spain
# 272           93  Marc Marquez  MotoGP    2024        Spain
# 273           93  Marc Marquez  MotoGP    2025        Spain
#
#                   motorcycle                             team  \
# 0                   Mahindra             Mapfre Team Mahindra
# 1                   Mahindra  Pull & Bear Aspar Mahindra Team
# ...
