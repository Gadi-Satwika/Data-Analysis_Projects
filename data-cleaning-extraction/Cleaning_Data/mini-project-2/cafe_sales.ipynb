# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('dirty_cafe_sales.csv')

# %%
df1
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df1.drop_duplicates(inplace = True)
df1
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
#df1.dropna(subset = ['Item','Transaction Date'])

# %%
mode_value = df1['Quantity'].mode()

# %%
df1.replace(['UNKNOWN','ERROR'],pd.NA,inplace = True)

# %%
df1.loc[:,'Quantity'].fillna(mode_value[0],inplace = True)
# Out:
# /tmp/ipykernel_7164/2479949366.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1.loc[:,'Quantity'].fillna(mode_value[0],inplace = True)

# %%
df1.loc[:,'Price Per Unit'].fillna(price[0],inplace = True)
# Out:
# /tmp/ipykernel_7164/4245097391.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1.loc[:,'Price Per Unit'].fillna(price[0],inplace = True)

# %%
df1['Quantity'] = df1['Quantity'].astype(int)
df1['Price Per Unit'] = df1['Price Per Unit'].astype(float)

# %%
df1.dtypes
# Out:
# Transaction ID       object
# Item                 object
# Quantity              int64
# Price Per Unit      float64
# Total Spent          object
# Payment Method       object
# Location             object
# Transaction Date     object
# dtype: object

# %%
df1['Total Spent'] = df1['Quantity'] * df1['Price Per Unit']

# %%
df1
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee         2             2.0          4.0
# 1       TXN_4977031      Cake         4             3.0         12.0
# 2       TXN_4271903    Cookie         4             1.0          4.0
# 3       TXN_7034554     Salad         2             5.0         10.0
# 4       TXN_3160411    Coffee         2             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee         2             2.0          4.0
# 9996    TXN_9659401       NaN         3             3.0          9.0
# 9997    TXN_5255387    Coffee         4             2.0          8.0
# 9998    TXN_7695629    Cookie         3             3.0          9.0
# 9999    TXN_6170729  Sandwich         3             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# ...

# %%
df1.loc[:,'Payment Method'].fillna('-',inplace = True)
df1.loc[:,'Location'].fillna('-',inplace = True)
# Out:
# /tmp/ipykernel_7164/2658502736.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1.loc[:,'Payment Method'].fillna('-',inplace = True)
# /tmp/ipykernel_7164/2658502736.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df1.isnull().sum()
# Out:
# Transaction ID        0
# Item                969
# Quantity              0
# Price Per Unit        0
# Total Spent           0
# Payment Method        0
# Location              0
# Transaction Date    460
# dtype: int64

# %%
df1.dropna(subset = ['Item','Transaction Date'],inplace = True)

# %%
df1.to_csv('/home/rgukt/Python/data-cleaning-project-2/cleaned_data.csv')
