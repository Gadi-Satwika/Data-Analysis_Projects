# %%
#This is data-set-1
#Cleaning the data

# %%
import pandas as pd

# %%
df1 = pd.read_csv('student_admission_record_dirty.csv')

# %% [markdown]
# #Explore and understand the data

# %%
df1
# Out:
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0                   68.90
# 1      Waqar  21.0  Female                  99.0                   60.73
# 2     Bushra  17.0    Male                  89.0                     NaN
# 3      Aliya  17.0    Male                  55.0                   85.29
# 4      Bilal  20.0    Male                  65.0                   61.13
# ..       ...   ...     ...                   ...                     ...
# 152      Ali  19.0  Female                  85.0                   78.09
# 153    Bilal  17.0  Female                  81.0                   84.40
# 154   Fatima  21.0  Female                  98.0                   50.86
# 155   Shoaib  -1.0    Male                  91.0                   80.12
# 156     Maaz  17.0    Male                  88.0                   86.85
#
#           City Admission Status
# 0       Quetta         Rejected
# ...

# %%
df1.isnull().sum()
# Out:
# Name                      10
# Age                       10
# Gender                    10
# Admission Test Score      11
# High School Percentage    11
# City                      10
# Admission Status          10
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 6

# %%
df1.nunique() #No of unique values in each column
# Out:
# Name                       64
# Age                         9
# Gender                      2
# Admission Test Score       49
# High School Percentage    129
# City                        7
# Admission Status            2
# dtype: int64

# %%
#So there are duplicates and null values, let's start cleaning the data

# %%
df1 = df1.drop_duplicates()
df1
# Out:
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0                   68.90
# 1      Waqar  21.0  Female                  99.0                   60.73
# 2     Bushra  17.0    Male                  89.0                     NaN
# 3      Aliya  17.0    Male                  55.0                   85.29
# 4      Bilal  20.0    Male                  65.0                   61.13
# ..       ...   ...     ...                   ...                     ...
# 152      Ali  19.0  Female                  85.0                   78.09
# 153    Bilal  17.0  Female                  81.0                   84.40
# 154   Fatima  21.0  Female                  98.0                   50.86
# 155   Shoaib  -1.0    Male                  91.0                   80.12
# 156     Maaz  17.0    Male                  88.0                   86.85
#
#           City Admission Status
# 0       Quetta         Rejected
# ...

# %%
df1.loc[:,'Age'] = df1['Age'].fillna(df1['Age'].mean())
df1.loc[:,['Gender','City']] = df1[['Gender','City']].fillna('Unknown')
df1.loc[:,'High School Percentage'] = df1['High School Percentage'].fillna(df1['High School Percentage'].mean())

# %%
df1.isnull().sum()
# Out:
# Name                      10
# Age                        0
# Gender                     0
# Admission Test Score      11
# High School Percentage     0
# City                       0
# Admission Status          10
# dtype: int64

# %%
df1.loc[:,'Admission Test Score'] = df1['Admission Test Score'].astype(float)

# %%
df1.dtypes
# Out:
# Name                       object
# Age                       float64
# Gender                     object
# Admission Test Score      float64
# High School Percentage    float64
# City                       object
# Admission Status           object
# dtype: object

# %%
df1
# Out:
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0               68.900000
# 1      Waqar  21.0  Female                  99.0               60.730000
# 2     Bushra  17.0    Male                  89.0               75.165929
# 3      Aliya  17.0    Male                  55.0               85.290000
# 4      Bilal  20.0    Male                  65.0               61.130000
# ..       ...   ...     ...                   ...                     ...
# 152      Ali  19.0  Female                  85.0               78.090000
# 153    Bilal  17.0  Female                  81.0               84.400000
# 154   Fatima  21.0  Female                  98.0               50.860000
# 155   Shoaib  -1.0    Male                  91.0               80.120000
# 156     Maaz  17.0    Male                  88.0               86.850000
#
#           City Admission Status
# 0       Quetta         Rejected
# ...

# %%
df1.dropna(inplace = True)
# Out:
# /tmp/ipykernel_48323/225149428.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(inplace = True)

# %%
df1.isnull().sum()
# Out:
# Name                      0
# Age                       0
# Gender                    0
# Admission Test Score      0
# High School Percentage    0
# City                      0
# Admission Status          0
# dtype: int64

# %%
#Start Working with inconsistent values

# %%
median = df1['Age'].median()

# %%
df1.loc[ (df1['Age']<17) | (df1['Age']>24),'Age' ] = int(median)

# %%
df1
# Out:
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0               68.900000
# 2     Bushra  17.0    Male                  89.0               75.165929
# 3      Aliya  17.0    Male                  55.0               85.290000
# 7      Rabia  20.0  Female                  82.0               55.670000
# 8     Rohail  17.0    Male                  64.0               75.165929
# ..       ...   ...     ...                   ...                     ...
# 152      Ali  19.0  Female                  85.0               78.090000
# 153    Bilal  17.0  Female                  81.0               84.400000
# 154   Fatima  21.0  Female                  98.0               50.860000
# 155   Shoaib  20.0    Male                  91.0               80.120000
# 156     Maaz  17.0    Male                  88.0               86.850000
#
#           City Admission Status
# 0       Quetta         Rejected
# ...

# %%
median_school = df1['High School Percentage'].median()

# %%
df1.loc[ (df1['High School Percentage'] <0) | (df1['High School Percentage'] >100) , 'High School Percentage'] = median_school

# %%
df1
# Out:
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0               68.900000
# 2     Bushra  17.0    Male                  89.0               75.165929
# 3      Aliya  17.0    Male                  55.0               85.290000
# 7      Rabia  20.0  Female                  82.0               55.670000
# 8     Rohail  17.0    Male                  64.0               75.165929
# ..       ...   ...     ...                   ...                     ...
# 152      Ali  19.0  Female                  85.0               78.090000
# 153    Bilal  17.0  Female                  81.0               84.400000
# 154   Fatima  21.0  Female                  98.0               50.860000
# 155   Shoaib  20.0    Male                  91.0               80.120000
# 156     Maaz  17.0    Male                  88.0               86.850000
#
#           City Admission Status
# 0       Quetta         Rejected
# ...

# %%
df1.to_excel('/home/rgukt/Python/data-extraction-project-5/cleaned_data.xlsx')
